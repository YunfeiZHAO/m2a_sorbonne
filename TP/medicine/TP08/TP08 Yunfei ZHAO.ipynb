# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([10**4, 5*(10**4), 10**5, 10**6, 10**7, 5*10**7])
y = np.array([1.69, 2.97, 2.69, 6.21, 34.57, 115.31])
plt.plot(x, y)
plt.show()

# %%
plt.plot(np.log(x), y)
plt.show()

# %%
plt.plot(np.log(x) * x, x)
plt.show()
